# %% [markdown]
# <a href="https://colab.research.google.com/github/BOSOEK/Machine_Learning_with_Book/blob/main/Deep_Learning_Chatbot_for_First_Time/Models/RNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # RNN (순환 신경망)
# 은닉층 출력값을 출력층과 그 다음 시점의 은닉층 노드의 입력으로 전달해 순환하는 특징이 있다.
#
# RNN 모델은 문제 해결에 따라 __many-to-one__, __one-to-many__, __many-to-many__로 나뉜다.

# %%
# sin 곡선 예측 RNN 모델
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, LSTM, SimpleRNN

# time step만큼 시퀀스 데이터 분리
def split_sequence(sequence, step):
    x, y = list(), list()

    for i in range(len(sequence)):
        end_idx = i+step
        if end_idx > len(sequence) -1 :
            break

        seq_x, seq_y = sequence[i:end_idx], sequence[end_idx]
        x.append(seq_x)
        y.append(seq_y)
    return np.array(x), np.array(y)

# sin 함수 학습 데이터
x = [i for i in np.arange(start = -10, stop=10, step=0.1)]
train_y = [np.sin(i) for i in x]

# 하이퍼 파라미터
n_timesteps = 15
n_features = 1

# 시퀀스 나누기
train_x, train_y = split_sequence(train_y, step=n_timesteps)
print('shape x:{} / y:{}'.format(train_x.shape, train_y.shape))

# RNN 입력 벡터 크기를 맞추기 위해 벡터 차원 크기 변경
train_x = train_x.reshape(train_x.shape[0], train_x.shape[1], n_features)
print('train_x.shape = {}'.format(train_x.shape))
print('train_y.shape = {}'.format(train_y.shape))

# RNN 모델 정의
model = Sequential()
model.add(SimpleRNN(units=10, return_sequences=False, input_shape=(n_timesteps, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# 모델 학습
np.random.seed(0)
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(
    monitor='loss',
    patience=5,
    mode='auto')
history = model.fit(train_x, train_y, epochs = 1000, callbacks = [early_stopping])

# loss 그래프 생성
plt.plot(history.history['loss'], label='loss')
plt.legend(loc='upper right')
plt.show()

# 테스트 데이터셋 생성
test_x = np.arange(10, 20, 0.1)
calc_y = np.cos(test_x)  # 테스트 정답 

# RNN 모델 예측 및 로그 저장
test_y = calc_y[:n_timesteps]
for i in range(len(test_x) - n_timesteps):
    net_input = test_y[i : i + n_timesteps]
    net_input = net_input.reshape((1, n_timesteps, n_features))
    train_y = model.predict(net_input, verbose=0)
    print(test_y.shape, train_y.shape, i, i+n_timesteps)
    test_y = np.append(test_y, train_y)

# 결과 그래프
plt.plot(test_x, calc_y, label='ground truth', color='orange')
plt.plot(test_x, test_y, label='predictions', color='blue')
plt.legend(loc='upper left')
plt.ylim(-2, 2)
plt.show()
# Out:
# shape x:(185, 15) / y:(185,)
# train_x.shape = (185, 15, 1)
# train_y.shape = (185,)
# Epoch 1/1000
# 6/6 [==============================] - 1s 5ms/step - loss: 0.0539
# Epoch 2/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0313
# Epoch 3/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0201
# Epoch 4/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0146
# Epoch 5/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0131
# Epoch 6/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.0119
# Epoch 7/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0109
# Epoch 8/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0094
# Epoch 9/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0083
# Epoch 10/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0073
# Epoch 11/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0065
# Epoch 12/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0057
# Epoch 13/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 14/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0046
# Epoch 15/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0039
# Epoch 16/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0034
# Epoch 17/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0030
# Epoch 18/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0026
# Epoch 19/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0022
# Epoch 20/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0019
# Epoch 21/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0017
# Epoch 22/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.0015
# Epoch 23/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 0.0013
# Epoch 24/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 0.0011
# Epoch 25/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.1439e-04
# Epoch 26/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 7.9418e-04
# Epoch 27/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 6.8807e-04
# Epoch 28/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 6.1615e-04
# Epoch 29/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.4855e-04
# Epoch 30/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 4.9525e-04
# Epoch 31/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.4994e-04
# Epoch 32/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 4.1304e-04
# Epoch 33/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 3.8637e-04
# Epoch 34/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6228e-04
# Epoch 35/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4909e-04
# Epoch 36/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2217e-04
# Epoch 37/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 3.1266e-04
# Epoch 38/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.9051e-04
# Epoch 39/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 2.8280e-04
# Epoch 40/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.6437e-04
# Epoch 41/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.5516e-04
# Epoch 42/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.3950e-04
# Epoch 43/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.2613e-04
# Epoch 44/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.1333e-04
# Epoch 45/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 2.0107e-04
# Epoch 46/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.9265e-04
# Epoch 47/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 1.8218e-04
# Epoch 48/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.7207e-04
# Epoch 49/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.6458e-04
# Epoch 50/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.5359e-04
# Epoch 51/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.4929e-04
# Epoch 52/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3695e-04
# Epoch 53/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.3326e-04
# Epoch 54/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2162e-04
# Epoch 55/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.2074e-04
# Epoch 56/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 1.1317e-04
# Epoch 57/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 1.0539e-04
# Epoch 58/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 1.0203e-04
# Epoch 59/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 9.5302e-05
# Epoch 60/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 9.0299e-05
# Epoch 61/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.4883e-05
# Epoch 62/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 8.0896e-05
# Epoch 63/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.7156e-05
# Epoch 64/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 7.3214e-05
# Epoch 65/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.9414e-05
# Epoch 66/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.6323e-05
# Epoch 67/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 6.4834e-05
# Epoch 68/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 6.2706e-05
# Epoch 69/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.9378e-05
# Epoch 70/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.7439e-05
# Epoch 71/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.8671e-05
# Epoch 72/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.3760e-05
# Epoch 73/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 5.4547e-05
# Epoch 74/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 5.0221e-05
# Epoch 75/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 4.9687e-05
# Epoch 76/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 4.7511e-05
# Epoch 77/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.5980e-05
# Epoch 78/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 4.6421e-05
# Epoch 79/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.4837e-05
# Epoch 80/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 4.4347e-05
# Epoch 81/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.3688e-05
# Epoch 82/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.2553e-05
# Epoch 83/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.1171e-05
# Epoch 84/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 4.0879e-05
# Epoch 85/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 4.0421e-05
# Epoch 86/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.9531e-05
# Epoch 87/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.9820e-05
# Epoch 88/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.8019e-05
# Epoch 89/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.8336e-05
# Epoch 90/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7792e-05
# Epoch 91/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7461e-05
# Epoch 92/1000
# 6/6 [==============================] - 0s 4ms/step - loss: 3.7055e-05
# Epoch 93/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.7209e-05
# Epoch 94/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.9006e-05
# Epoch 95/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6340e-05
# Epoch 96/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6723e-05
# Epoch 97/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5247e-05
# Epoch 98/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5412e-05
# Epoch 99/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4718e-05
# Epoch 100/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5318e-05
# Epoch 101/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.5898e-05
# Epoch 102/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 3.4274e-05
# Epoch 103/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.4255e-05
# Epoch 104/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3932e-05
# Epoch 105/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3444e-05
# Epoch 106/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6258e-05
# Epoch 107/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.6032e-05
# Epoch 108/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3252e-05
# Epoch 109/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3689e-05
# Epoch 110/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.3881e-05
# Epoch 111/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2724e-05
# Epoch 112/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2299e-05
# Epoch 113/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 3.2439e-05
# Epoch 114/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3.2791e-05
# Epoch 115/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 3.2915e-05
# Epoch 116/1000
# 6/6 [==============================] - 0s 5ms/step - loss: 3